# %% [markdown]
# ## Import and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

plt.style.use('ggplot')
# pd.set_option('max_columns', 60)

# %%
df = pd.read_csv('../Code/qld_car_crash/crash_data_queensland_1_crash_locations.csv')

# %%
df.shape
# Out:
# (367230, 52)

# %%
df.head()
# Out:
#    Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                 1       Hospitalisation        2001     January
# 1                 2  Property damage only        2001     January
# 2                 3          Minor injury        2001     January
# 3                 4  Property damage only        2001     January
# 4                 5  Property damage only        2001     January
#
#   Crash_Day_Of_Week  Crash_Hour Crash_Nature      Crash_Type  Crash_Longitude  \
# 0            Monday           6      Head-on   Multi-Vehicle       153.052207
# 1         Wednesday           9        Angle   Multi-Vehicle       153.064920
# 2          Thursday           8     Rear-end   Multi-Vehicle       153.058444
# 3            Sunday           8   Hit object  Single Vehicle       153.081083
# 4           Tuesday          16   Overturned  Single Vehicle         0.000009
#
#    Crash_Latitude  ... Count_Casualty_MedicallyTreated  \
# ...

# %%
df.columns
# Out:
# Index(['Crash_Ref_Number', 'Crash_Severity', 'Crash_Year', 'Crash_Month',
#        'Crash_Day_Of_Week', 'Crash_Hour', 'Crash_Nature', 'Crash_Type',
#        'Crash_Longitude', 'Crash_Latitude', 'Crash_Street',
#        'Crash_Street_Intersecting', 'State_Road_Name', 'Loc_Suburb',
#        'Loc_Local_Government_Area', 'Loc_Post_Code', 'Loc_Police_Division',
#        'Loc_Police_District', 'Loc_Police_Region',
#        'Loc_Queensland_Transport_Region', 'Loc_Main_Roads_Region',
#        'Loc_ABS_Statistical_Area_2', 'Loc_ABS_Statistical_Area_3',
#        'Loc_ABS_Statistical_Area_4', 'Loc_ABS_Remoteness',
#        'Loc_State_Electorate', 'Loc_Federal_Electorate',
#        'Crash_Controlling_Authority', 'Crash_Roadway_Feature',
#        'Crash_Traffic_Control', 'Crash_Speed_Limit',
#        'Crash_Road_Surface_Condition', 'Crash_Atmospheric_Condition',
#        'Crash_Lighting_Condition', 'Crash_Road_Horiz_Align',
# ...

# %%
df.dtypes
# Out:
# Crash_Ref_Number                     int64
# Crash_Severity                      object
# Crash_Year                           int64
# Crash_Month                         object
# Crash_Day_Of_Week                   object
# Crash_Hour                           int64
# Crash_Nature                        object
# Crash_Type                          object
# Crash_Longitude                    float64
# Crash_Latitude                     float64
# Crash_Street                        object
# Crash_Street_Intersecting           object
# State_Road_Name                     object
# Loc_Suburb                          object
# Loc_Local_Government_Area           object
# Loc_Post_Code                       object
# Loc_Police_Division                 object
# Loc_Police_District                 object
# Loc_Police_Region                   object
# Loc_Queensland_Transport_Region     object
# Loc_Main_Roads_Region               object
# Loc_ABS_Statistical_Area_2          object
# ...

# %%
df.describe()
# Out:
#        Crash_Ref_Number     Crash_Year     Crash_Hour  Crash_Longitude  \
# count     367230.000000  367230.000000  367230.000000    367230.000000
# mean      183615.500000    2009.517373      12.802726       151.488255
# std       106010.314015       5.902409       5.290238         6.638351
# min            1.000000    2001.000000       0.000000         0.000009
# 25%        91808.250000    2005.000000       9.000000       151.933278
# 50%       183615.500000    2009.000000      13.000000       152.986475
# 75%       275422.750000    2014.000000      17.000000       153.085977
# max       367230.000000    2021.000000      23.000000       153.550268
#
#        Crash_Latitude  Crash_DCA_Code  Count_Casualty_Fatality  \
# count   367230.000000   367146.000000            367230.000000
# mean       -25.772225      393.829803                 0.016349
# std          3.401877      253.879362                 0.140855
# min        -29.145815        0.000000                 0.000000
# ...

# %% [markdown]
# ## Data Preparation

# %%
df.head()
# Out:
#    Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                 1       Hospitalisation        2001     January
# 1                 2  Property damage only        2001     January
# 2                 3          Minor injury        2001     January
# 3                 4  Property damage only        2001     January
# 4                 5  Property damage only        2001     January
#
#   Crash_Day_Of_Week  Crash_Hour Crash_Nature      Crash_Type  Crash_Longitude  \
# 0            Monday           6      Head-on   Multi-Vehicle       153.052207
# 1         Wednesday           9        Angle   Multi-Vehicle       153.064920
# 2          Thursday           8     Rear-end   Multi-Vehicle       153.058444
# 3            Sunday           8   Hit object  Single Vehicle       153.081083
# 4           Tuesday          16   Overturned  Single Vehicle         0.000009
#
#    Crash_Latitude  ... Count_Casualty_MedicallyTreated  \
# ...

# %%
df = df[[#'Crash_Ref_Number', 
        'Crash_Severity', 'Crash_Year', 'Crash_Month', 
        'Crash_Day_Of_Week', 'Crash_Hour', 'Crash_Nature', 'Crash_Type',
        'Crash_Longitude', 'Crash_Latitude', 
    #'Crash_Street', 'Crash_Street_Intersecting', 'State_Road_Name', 
        'Loc_Suburb', 'Loc_Local_Government_Area', 'Loc_Post_Code', 
#        'Loc_Police_Division',
#        'Loc_Police_District', 'Loc_Police_Region',
#        'Loc_Queensland_Transport_Region', 'Loc_Main_Roads_Region',
#        'Loc_ABS_Statistical_Area_2', 'Loc_ABS_Statistical_Area_3',
#        'Loc_ABS_Statistical_Area_4', 'Loc_ABS_Remoteness',
#        'Loc_State_Electorate', 'Loc_Federal_Electorate',
#        'Crash_Controlling_Authority', 'Crash_Roadway_Feature',
#        'Crash_Traffic_Control', 'Crash_Speed_Limit',
#        'Crash_Road_Surface_Condition', 'Crash_Atmospheric_Condition',
#        'Crash_Lighting_Condition', 'Crash_Road_Horiz_Align',
#        'Crash_Road_Vert_Align', 'Crash_DCA_Code', 'Crash_DCA_Description',
#        'Crash_DCA_Group_Description', 'DCA_Key_Approach_Dir',
       'Count_Casualty_Fatality', 'Count_Casualty_Hospitalised',
       'Count_Casualty_MedicallyTreated', 'Count_Casualty_MinorInjury',
       'Count_Casualty_Total', 'Count_Unit_Car', 'Count_Unit_Motorcycle_Moped',
       'Count_Unit_Truck', 'Count_Unit_Bus', 'Count_Unit_Bicycle',
       'Count_Unit_Pedestrian', 'Count_Unit_Other']].copy()

# %%
df.head()
# Out:
#          Crash_Severity  Crash_Year Crash_Month Crash_Day_Of_Week  Crash_Hour  \
# 0       Hospitalisation        2001     January            Monday           6
# 1  Property damage only        2001     January         Wednesday           9
# 2          Minor injury        2001     January          Thursday           8
# 3  Property damage only        2001     January            Sunday           8
# 4  Property damage only        2001     January           Tuesday          16
#
#   Crash_Nature      Crash_Type  Crash_Longitude  Crash_Latitude  \
# 0      Head-on   Multi-Vehicle       153.052207      -27.586358
# 1        Angle   Multi-Vehicle       153.064920      -27.595907
# 2     Rear-end   Multi-Vehicle       153.058444      -27.599409
# 3   Hit object  Single Vehicle       153.081083      -27.598882
# 4   Overturned  Single Vehicle         0.000009       -0.000010
#
#         Loc_Suburb  ... Count_Casualty_MedicallyTreated  \
# ...

# %%
df.shape
# Out:
# (367230, 24)

# %%
df.dtypes
# Out:
# Crash_Severity                      object
# Crash_Year                           int64
# Crash_Month                         object
# Crash_Day_Of_Week                   object
# Crash_Hour                           int64
# Crash_Nature                        object
# Crash_Type                          object
# Crash_Longitude                    float64
# Crash_Latitude                     float64
# Loc_Suburb                          object
# Loc_Local_Government_Area           object
# Loc_Post_Code                       object
# Count_Casualty_Fatality              int64
# Count_Casualty_Hospitalised          int64
# Count_Casualty_MedicallyTreated      int64
# Count_Casualty_MinorInjury           int64
# Count_Casualty_Total                 int64
# Count_Unit_Car                       int64
# Count_Unit_Motorcycle_Moped          int64
# Count_Unit_Truck                     int64
# Count_Unit_Bus                       int64
# Count_Unit_Bicycle                   int64
# ...

# %%
df.isna().sum()
# Out:
# Crash_Severity                     0
# Crash_Year                         0
# Crash_Month                        0
# Crash_Day_Of_Week                  0
# Crash_Hour                         0
# Crash_Nature                       0
# Crash_Type                         0
# Crash_Longitude                    0
# Crash_Latitude                     0
# Loc_Suburb                         0
# Loc_Local_Government_Area          0
# Loc_Post_Code                      0
# Count_Casualty_Fatality            0
# Count_Casualty_Hospitalised        0
# Count_Casualty_MedicallyTreated    0
# Count_Casualty_MinorInjury         0
# Count_Casualty_Total               0
# Count_Unit_Car                     0
# Count_Unit_Motorcycle_Moped        0
# Count_Unit_Truck                   0
# Count_Unit_Bus                     0
# Count_Unit_Bicycle                 0
# Count_Unit_Pedestrian              0
# Count_Unit_Other                   0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
#               Crash_Severity  Crash_Year Crash_Month Crash_Day_Of_Week  \
# 127563       Hospitalisation        2014    February            Friday
# 219471     Medical treatment        2001    February            Monday
# 279938  Property damage only        2010        June          Thursday
# 305427       Hospitalisation        2017      August           Tuesday
# 332661  Property damage only        2002        July          Saturday
# 347556     Medical treatment        2020        June          Thursday
# 366269     Medical treatment        2020        July            Friday
#
#         Crash_Hour       Crash_Nature      Crash_Type  Crash_Longitude  \
# 127563          16              Angle   Multi-Vehicle       153.002195
# 219471           7         Hit object  Single Vehicle         0.000009
# 279938          21           Rear-end   Multi-Vehicle       146.736325
# 305427          12  Fall from vehicle  Single Vehicle       142.526286
# ...

# %%
df.columns
# Out:
# Index(['Crash_Severity', 'Crash_Year', 'Crash_Month', 'Crash_Day_Of_Week',
#        'Crash_Hour', 'Crash_Nature', 'Crash_Type', 'Crash_Longitude',
#        'Crash_Latitude', 'Loc_Suburb', 'Loc_Local_Government_Area',
#        'Loc_Post_Code', 'Count_Casualty_Fatality',
#        'Count_Casualty_Hospitalised', 'Count_Casualty_MedicallyTreated',
#        'Count_Casualty_MinorInjury', 'Count_Casualty_Total', 'Count_Unit_Car',
#        'Count_Unit_Motorcycle_Moped', 'Count_Unit_Truck', 'Count_Unit_Bus',
#        'Count_Unit_Bicycle', 'Count_Unit_Pedestrian', 'Count_Unit_Other'],
#       dtype='object')

# %%
df = df.loc[~df.duplicated()] \
    .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (367223, 24)

# %% [markdown]
# ## Feature Understanding

# %%
df['Crash_Year'].value_counts()
# Out:
# 2008    23525
# 2004    23441
# 2005    23077
# 2009    22942
# 2007    22847
# 2010    22536
# 2006    22454
# 2003    22393
# 2002    22315
# 2001    22022
# 2021    13353
# 2019    12960
# 2018    12950
# 2012    12760
# 2013    12751
# 2017    12731
# 2011    12689
# 2014    12648
# 2016    12551
# 2015    12156
# 2020    12122
# Name: Crash_Year, dtype: int64

# %%
year_order = []

for i in range(2001,2022):
    year_order.append(i)

print(year_order)
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
ax = df['Crash_Year'].value_counts() \
    .loc[year_order] \
    .plot(kind='bar', title="QLD Crash Count by Year")
ax.set_xlabel('Year')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Upon reviewing the dataset notes it was found that "Property damage only crashes ceased to be reported/recorded by Queensland Police Service after 31 December 2010." Therefore, this has been dropped from the data set.

# %%
df.query('Crash_Severity == "Property damage only"')
# Out:
#               Crash_Severity  Crash_Year Crash_Month Crash_Day_Of_Week  \
# 1       Property damage only        2001     January         Wednesday
# 3       Property damage only        2001     January            Sunday
# 4       Property damage only        2001     January           Tuesday
# 5       Property damage only        2001     January         Wednesday
# 6       Property damage only        2001     January         Wednesday
# ...                      ...         ...         ...               ...
# 362922  Property damage only        2002        July          Thursday
# 365141  Property damage only        2001    February          Saturday
# 365153  Property damage only        2001      August            Friday
# 365155  Property damage only        2001   September          Saturday
# 365161  Property damage only        2002    February          Saturday
#
#         Crash_Hour Crash_Nature      Crash_Type  Crash_Longitude  \
# ...

# %%
df = df[df.Crash_Severity != 'Property damage only'] \
    .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (279793, 24)

# %%
ax = df['Crash_Year'].value_counts() \
    .loc[year_order] \
    .plot(kind='bar', title="QLD Crash Count by Year")
ax.set_xlabel('Year')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Crash_Hour'].plot(kind='hist', bins=24, title='Crashes by Hour')
# Out:
# <AxesSubplot: title={'center': 'Crashes by Hour'}, ylabel='Frequency'>

# %%
df['Crash_Day_Of_Week'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df['Crash_Month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >
